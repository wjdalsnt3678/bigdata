# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdalsnt3678/bigdata/blob/main/Minsu_Jung2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
val1 = [2,3,5,4,0.2,0.5,8,1,0.6,0.2]
print(len(val1))
val2 = [6,2,8,7,4,0.11,1.66,2.88,1.99,1.55]
print(len(val2))
# Out:
# 10
# 10

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.scatter(val1,val2)

# %%
import seaborn as sns
import pandas as pd
df = pd.DataFrame([val1,va2]).T
df.columns = ['val1', 'val2']
print(df)

sns.heatmap(df)
# Out:
#    val1  val2
# 0   2.0  6.00
# 1   3.0  2.00
# 2   5.0  8.00
# 3   4.0  7.00
# 4   0.2  4.00
# 5   0.5  0.11
# 6   8.0  1.66
# 7   1.0  2.88
# 8   0.6  1.99
# 9   0.2  1.55
# <Axes: >

# %%
df.corr(method='pearson')
# Out:
#           val1      val2
# val1  1.000000  0.299515
# val2  0.299515  1.000000

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

sns.pairplot(iris, hue="species",height=3)
plt.show()

# %%
import nltk
nltk.download('inaugural')

from nltk.corpus import inaugural
print(len(inaugural.fileids()))
print(inaugural.fileids() [:5])
[fileid[:4] for fileid in inaugural. fileids() ] [:5]
# Out:
# 59
# ['1789-Washington.txt', '1793-Washington.txt', '1797-Adams.txt', '1801-Jefferson.txt', '1805-Jefferson.txt']
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# ['1789', '1793', '1797', '1801', '1805']
